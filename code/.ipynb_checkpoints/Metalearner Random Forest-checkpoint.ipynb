# %%
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from imblearn.over_sampling import SMOTE
from collections import Counter
from sklearn import metrics
from sklearn import svm
import pandas as pd
import numpy as np
import sys
import os

# %%
is_vae = True

# %%
# Just choose the name of the dataset directory
DATA_DIR = '/Users/tomas/Documents/FEUP/Tese/data/ml-20m/processed_70_10_20'
if is_vae:
    PARSE_DATA_DIR = os.path.join(DATA_DIR, 'embeddings/vae')
else:
    PARSE_DATA_DIR = os.path.join(DATA_DIR, 'embeddings/cdae')

# %%
file = 'metadataset_k_20.csv'
os.path.join(PARSE_DATA_DIR, file )
# Out:
# '/Users/tomas/Documents/FEUP/Tese/data/ml-20m/processed_70_10_20/embeddings/vae/metadataset_k_20.csv'

# %%
#read in the data using pandas
metadataset = pd.read_csv(os.path.join(PARSE_DATA_DIR, file ))
#metadataset = metadataset[metadataset.first_place != 'zeroes']
metadataset.head()
# Out:
#    original_id         1         2         3         4         5         6  \
# 0         7648 -0.431028  0.273519  0.000467 -0.021366  0.411798  0.445795
# 1        10208  0.351687 -0.626017  0.034143 -0.080265  0.101129 -0.229498
# 2        13315 -0.706174 -0.031290 -0.005091 -0.097111  0.111871  0.484369
# 3        16144  0.672244 -0.958536 -0.005133 -0.093083  0.118219 -0.325690
# 4        18064 -0.813108  0.897909 -0.105261  0.080410  0.099298 -1.109625
#
#           7         8         9  ...       192       193       194       195  \
# 0  1.206461  0.437548 -0.670044  ...  1.261934  0.238986  0.150137 -0.024725
# 1  0.261393 -1.189405 -0.451783  ...  0.964082  0.825656  0.064932  0.042978
# 2  0.737223 -1.132764  1.119018  ...  1.040254 -1.375516 -0.064951  0.030435
# 3  1.434977  0.006304 -0.780396  ...  1.159395 -0.746610  0.042197  0.038217
# 4  2.775797  0.139941 -0.745728  ...  0.584199  0.619601  0.027197  0.051431
#
#         196       197       198       199       200        first_place
# 0 -0.349221  3.509393 -0.146421  1.508804 -0.859744           als_ndcg
# 1 -1.043557  0.562128  0.234560  0.813003  0.511105             zeroes
# 2  0.757224  0.444452  0.753969 -0.582505  0.761838           bpr_ndcg
# 3 -0.813577  1.753534 -0.063353 -0.829087 -1.122440  most_popular_ndcg
# 4 -1.668557  1.609979 -1.117613  1.222671 -2.145877           lmf_ndcg
#
# [5 rows x 202 columns]

# %% [markdown]
# ### Encode Target

# %%
#als:0
#bpr:1
#lmf:2
#most_pop_3
#zeros:4
target_pre = metadataset['first_place'].values 
label_encoder = LabelEncoder()
target = label_encoder.fit_transform(target_pre)

keys = label_encoder.classes_
values = label_encoder.transform(keys)
labels = dict(zip(values,keys))

# %% [markdown]
# ### Normalization Inputs

# %%
normalize = True

# %%
if normalize:
  #---- SET INPUTS -----
  scaler = StandardScaler()
  #Compute the mean and std to be used for later scaling.
  scaler.fit(metadataset.drop(columns=['first_place','original_id']))
  # Perform standardization by centering and scaling
  inputs_transform = scaler.transform(metadataset.drop(columns=['first_place','original_id']))
  inputs = pd.DataFrame(inputs_transform)
  inputs.head()
else:
  inputs = metadataset.drop(columns=['first_place','original_id'])

# %% [markdown]
# ### Model

# %%
kf = KFold(n_splits=5)
kf.get_n_splits()
print(kf)
# Out:
# KFold(n_splits=5, random_state=None, shuffle=False)

# %%
is_smote = False

# %%
params ={'max_features': 'auto', 'n_estimators': 100, 'bootstrap': True, 'max_depth': 150}

# %%
i = 1 
base_impact_with_zeroes = []
base_impact_without_zeroes_most = []
base_impact_without_zeroes_best = []
matrix = []
reports = []

base_impact_with_zeroes_without_true_zeroes = []
base_impact_without_zeroes_most_without_true_zeroes = []
base_impact_without_zeroes_best_without_true_zeroes = []

confusion_without_true_zeroes = []
reports_without_true_zeroes = []
for train_index, test_index in kf.split(inputs):
    print('iteration: ', i)
    #get data fold
    X_train, X_test = inputs.iloc[train_index], inputs.iloc[test_index]
    y_train, y_test = target[train_index], target[test_index]
    
    #start model 
    print('fit')
    clf = RandomForestClassifier(
        random_state=0,
        bootstrap=params['bootstrap'],
        max_depth=params['max_depth'],
        max_features=params['max_features'],
        n_estimators=params['n_estimators'], verbose=100, n_jobs=-1)
    
    
    if is_smote:
        print('dataset shape %s' % Counter(y_train))
        sm = SMOTE(random_state=42,n_jobs=4)
        X_train_re, y_train_re = sm.fit_resample(X_train, y_train)
        print('Resampled dataset shape %s' % Counter(y_train_re))

        clf.fit(X_train_re, y_train_re)
        print('predict')
    else:
        clf.fit(X_train, y_train)
        
    y_pred = clf.predict(X_test)
    
    
      #Remove users that are zeroes 
    data = {'real':  y_test,
        'pred': y_pred,
        'original_id':metadataset.iloc[test_index]['original_id'].values
    }
    df = pd.DataFrame (data, columns = ['real','pred','original_id'])
    df = df[df.real != 4]
    
    #wihtout zeroes users
    c_n_z = confusion_matrix(df.real,df.pred)
    r_n_z = classification_report(df.real,
                                    df.pred, 
                                   target_names=np.unique(metadataset['first_place'].values),
                                  output_dict=True,
                                 zero_division=1)
    
    bl_zeroes_n_z, bl_no_zeroes_most_n_z, bl_no_zeroes_best_n_z = base_level_eval(df.original_id,
             list(label_encoder.inverse_transform(df.pred)))

    base_impact_with_zeroes_without_true_zeroes.append(bl_zeroes_n_z)
    base_impact_without_zeroes_most_without_true_zeroes.append(bl_no_zeroes_most_n_z)
    base_impact_without_zeroes_best_without_true_zeroes.append(bl_no_zeroes_best_n_z)
    
    confusion_without_true_zeroes.append(c_n_z)
    reports_without_true_zeroes.append(r_n_z)
    
    
    
    report = classification_report(y_test, 
                               y_pred, 
                               target_names=np.unique(metadataset['first_place'].values),
                              output_dict=True)
    reports.append(report)
    
    bl_zeroes, bl_no_zeroes_most, bl_no_zeroes_best = base_level_eval(metadataset.iloc[test_index]['original_id'].values,
             list(label_encoder.inverse_transform(y_pred)))

    base_impact_with_zeroes.append(bl_zeroes)
    base_impact_without_zeroes_most.append(bl_no_zeroes_most)
    base_impact_without_zeroes_best.append(bl_no_zeroes_best)

    confusion = confusion_matrix(y_test,y_pred)
    matrix.append(confusion)
    np.set_printoptions(suppress=True)
    print('end: ', i)
    i+=1
# Out:
# iteration:  1
# fit
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# building tree 1 of 100building tree 2 of 100
# building tree 3 of 100building tree 4 of 100
#
#
# building tree 5 of 100[Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    2.8s
#
# building tree 6 of 100[Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.9s
#
# building tree 7 of 100[Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    2.9s
#
# building tree 8 of 100[Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    3.0s
#
# building tree 9 of 100[Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    8.0s
#
# building tree 10 of 100[Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    8.0s
#
# building tree 11 of 100[Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    8.1s
#
# building tree 12 of 100[Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    8.1s
#
# building tree 13 of 100[Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   10.9s
#
# building tree 14 of 100[Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   11.0s
#
# building tree 15 of 100[Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:   11.1s
#
# building tree 16 of 100[Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:   11.2s
#
# building tree 17 of 100[Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:   14.1s
#
# building tree 18 of 100[Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:   14.6s
#
# building tree 19 of 100[Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:   14.6s
#
# building tree 20 of 100[Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   14.7s
#
# building tree 21 of 100[Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   17.7s
#
# building tree 22 of 100[Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:   18.0s
#
# building tree 23 of 100[Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:   18.0s
#
# building tree 24 of 100[Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:   18.3s
#
# building tree 25 of 100[Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:   20.7s
#
# building tree 26 of 100[Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:   21.1s
#
# building tree 27 of 100[Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:   21.1s
#
# building tree 28 of 100[Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   21.3s
#
# building tree 29 of 100[Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   24.3s
#
# building tree 30 of 100[Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   24.4s
#
# building tree 31 of 100[Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:   24.6s
#
# building tree 32 of 100[Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:   24.8s
#
# building tree 33 of 100[Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:   27.2s
#
# building tree 34 of 100[Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:   27.3s
#
# building tree 35 of 100[Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:   27.5s
#
# building tree 36 of 100[Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:   27.6s
#
# building tree 37 of 100[Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   31.8s
#
# building tree 38 of 100[Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   31.8s
#
# building tree 39 of 100[Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:   32.4s
#
# building tree 40 of 100[Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:   32.5s
#
# building tree 41 of 100[Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:   36.6s
#
# building tree 42 of 100[Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:   36.7s
#
# building tree 43 of 100[Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:   37.0s
#
# building tree 44 of 100[Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:   37.3s
#
# building tree 45 of 100[Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:   41.0s
#
# building tree 46 of 100[Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   41.0s
#
# building tree 47 of 100[Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:   41.5s
#
# building tree 48 of 100[Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:   41.5s
#
# building tree 49 of 100[Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:   44.7s
#
# building tree 50 of 100[Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:   44.8s
#
# building tree 51 of 100[Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:   45.2s
#
# building tree 52 of 100[Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:   45.5s
#
# building tree 53 of 100[Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:   47.8s
#
# building tree 54 of 100[Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:   48.2s
#
# building tree 55 of 100[Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:   48.6s
#
# building tree 56 of 100[Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:   49.1s
#
# building tree 57 of 100[Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   50.9s
#
# building tree 58 of 100[Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:   51.3s
#
# building tree 59 of 100[Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:   51.6s
#
# building tree 60 of 100[Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:   52.1s
#
# building tree 61 of 100[Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:   54.2s
#
# building tree 62 of 100[Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:   54.8s
#
# building tree 63 of 100[Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:   55.1s
#
# building tree 64 of 100[Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:   55.8s
#
# building tree 65 of 100[Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:   60.0s
#
# building tree 66 of 100[Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:  1.0min
#
# building tree 67 of 100[Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:  1.0min
#
# building tree 68 of 100[Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  1.0min
#
# building tree 69 of 100[Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:  1.1min
#
# building tree 70 of 100[Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:  1.1min
#
# building tree 71 of 100[Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed:  1.1min
#
# building tree 72 of 100[Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:  1.1min
#
# building tree 73 of 100[Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:  1.1min
#
# building tree 74 of 100[Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed:  1.1min
#
# building tree 75 of 100[Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed:  1.1min
#
# building tree 76 of 100[Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed:  1.1min
#
# building tree 77 of 100[Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:  1.2min
#
# building tree 78 of 100[Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:  1.2min
#
# building tree 79 of 100[Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed:  1.2min
#
# building tree 80 of 100[Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:  1.2min
#
# building tree 81 of 100[Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:  1.2min
#
# building tree 82 of 100[Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed:  1.2min
#
# building tree 83 of 100[Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed:  1.2min
#
# building tree 84 of 100[Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:  1.2min
#
# building tree 85 of 100[Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:  1.3min
#
# building tree 86 of 100[Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:  1.3min
#
# building tree 87 of 100[Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed:  1.3min
#
# building tree 88 of 100[Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed:  1.3min
#
# building tree 89 of 100[Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed:  1.3min
#
# building tree 90 of 100[Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed:  1.3min
#
# building tree 91 of 100[Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed:  1.4min
#
# building tree 92 of 100[Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:  1.4min
#
# building tree 93 of 100[Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed:  1.4min
#
# building tree 94 of 100[Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:  1.4min
#
# building tree 95 of 100[Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed:  1.4min
#
# building tree 96 of 100[Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed:  1.4min
#
# building tree 97 of 100[Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed:  1.4min
#
# building tree 98 of 100
# building tree 99 of 100[Parallel(n_jobs=-1)]: Done  95 out of 100 | elapsed:  1.4min remaining:    4.6s
#
# building tree 100 of 100
# [Parallel(n_jobs=-1)]: Done  97 out of 100 | elapsed:  1.5min remaining:    2.7s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.5min finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done   6 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done   7 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done   8 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done   9 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  11 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  12 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  13 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  14 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  15 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  16 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done  17 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  18 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  19 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  20 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  21 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  22 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  23 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  25 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  26 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  27 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  28 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  29 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done  31 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done  32 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done  33 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done  35 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done  36 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done  37 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done  38 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done  39 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done  40 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done  41 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done  43 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done  44 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done  45 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done  46 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done  47 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done  48 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done  49 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done  50 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done  51 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done  52 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done  53 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done  54 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done  55 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done  57 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done  58 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done  59 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done  60 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done  61 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done  62 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done  63 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done  64 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done  65 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done  66 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done  67 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done  69 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done  70 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done  71 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done  72 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done  73 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done  74 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done  75 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done  77 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done  78 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done  79 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done  80 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done  81 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done  82 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done  83 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done  84 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done  85 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done  86 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done  87 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done  89 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done  90 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done  91 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done  92 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done  93 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done  95 out of 100 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done  97 out of 100 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    0.8s finished
# starting base_level_eval
# 1.0 1.0
# 0.2789429456511299 0.5514997039452156
# 0.8900463168893454 0.3447702602206777
# %usesr that prediction ndcg is better than ALS  0.15887893618986057
# %usesr that prediction ndcg is same than ALS 0.6379167051435959
# % users improved worse than 0.20320435866654354
# starting base_level_eval
# 1.0 1.0
# 0.2789429456511299 0.5514997039452156
# 0.8900463168893454 0.3447702602206777
# %usesr that prediction ndcg is better than ALS  0.13259093711467324
# %usesr that prediction ndcg is same than ALS 0.6978267570900123
# % users improved worse than 0.16958230579531441
# end:  1
# iteration:  2
# fit
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100building tree 4 of 100
#
# building tree 5 of 100[Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    2.7s
#
# building tree 6 of 100[Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.7s
#
# building tree 7 of 100[Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    2.7s
#
# building tree 8 of 100[Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    2.7s
#
# building tree 9 of 100[Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    5.5s
#
# building tree 10 of 100[Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    5.5s
#
# building tree 11 of 100[Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    5.5s
#
# building tree 12 of 100[Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    5.6s
#
# building tree 13 of 100[Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    8.2s
#
# building tree 14 of 100[Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    8.3s
#
# building tree 15 of 100[Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:    8.3s
#
# building tree 16 of 100[Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    8.4s
#
# building tree 17 of 100[Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:   10.9s
#
# building tree 18 of 100[Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:   10.9s
#
# building tree 19 of 100[Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:   11.0s
#
# building tree 20 of 100[Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   11.1s
# building tree 21 of 100[Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   13.6s
#
# building tree 22 of 100[Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:   13.6s
#
# building tree 23 of 100[Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:   13.7s
#
# building tree 24 of 100[Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:   13.9s
#
# building tree 25 of 100[Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:   16.2s
#
# building tree 26 of 100[Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:   16.3s
#
# building tree 27 of 100[Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:   16.4s
#
# building tree 28 of 100[Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   16.7s
#
# building tree 29 of 100[Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   18.9s
#
# building tree 30 of 100[Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   19.0s
#
# building tree 31 of 100[Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:   19.0s
#
# building tree 32 of 100[Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:   19.5s
#
# building tree 33 of 100[Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:   22.0s
#
# building tree 34 of 100[Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:   22.2s
#
# building tree 35 of 100[Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:   22.2s
#
# building tree 36 of 100[Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:   22.7s
#
# building tree 37 of 100[Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   24.9s
#
# building tree 38 of 100[Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   25.1s
#
# building tree 39 of 100[Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:   25.1s
#
# building tree 40 of 100[Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:   25.9s
#
# building tree 41 of 100[Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:   28.1s
#
# building tree 42 of 100[Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:   28.4s
#
# building tree 43 of 100[Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:   28.4s
#
# building tree 44 of 100[Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:   29.1s
#
# building tree 45 of 100[Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:   31.1s
#
# building tree 46 of 100[Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   31.3s
#
# building tree 47 of 100[Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:   31.4s
#
# building tree 48 of 100[Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:   32.0s
#
# building tree 49 of 100[Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:   34.0s
#
# building tree 50 of 100[Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:   34.3s
#
# building tree 51 of 100[Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:   34.3s
#
# building tree 52 of 100[Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:   35.0s

# %%
print('base level impact zeroes', np.mean(base_impact_with_zeroes))
print('base level impact  whithout zeroes, replaced most_pop', np.mean(base_impact_without_zeroes_most))
print('base level impact  whithout zeroes, replaced best', np.mean(base_impact_without_zeroes_best))
avg_reports = report_average(reports)
print_report(avg_reports)
print_confusion(np.mean( np.array(matrix),axis=0 ),labels)

# %%
print('base level impact zeroes', np.mean(base_impact_with_zeroes_without_true_zeroes))
print('base level impact  whithout zeroes, replaced most_pop', np.mean(base_impact_without_zeroes_most_without_true_zeroes))
print('base level impact  whithout zeroes, replaced best', np.mean(base_impact_without_zeroes_best_without_true_zeroes))

avg_reports = report_average(reports_without_true_zeroes)
print_report(avg_reports)
print_confusion(np.mean( np.array(confusion_without_true_zeroes),axis=0 ),labels)

# %% [markdown]
# #### print

# %%
def print_confusion(values, classes):
    from prettytable import PrettyTable
    x = PrettyTable()
    print(classes)

    names = []
    names.append('algorithm')
    names = names + list(classes.values())

    x.field_names = names

    i = 0
    for row in values:
        #row = np.array(row)
        r = []
        r.append(classes[i])
        row = r + list(row)
        #r.append(classes[i])
        #r = r + row
        #row = np.insert(row,0,'als')
        x.add_row(row)
        #r  = np.concatenate(csses[i],row[])
        i +=1
    print(x)
def report_average(reports):
    mean_dict = dict()
    for label in reports[0].keys():
        dictionary = dict()

        if label in 'accuracy':
            mean_dict[label] = sum(d[label] for d in reports) / len(reports)
            continue

        for key in reports[0][label].keys():
            dictionary[key] = sum(d[label][key] for d in reports) / len(reports)
        mean_dict[label] = dictionary

    return mean_dict
def print_report(avg_reports):
    from prettytable import PrettyTable
    x = PrettyTable()

    x.field_names = ["Algorithm", "Precision", "Recall", "F1"]

    for label in avg_reports.keys():
        if label in 'accuracy':
            x.add_row(['---','---','---','---'])
            continue
        x.add_row([label, 
                   avg_reports[label]['precision'], 
                   avg_reports[label]['recall'], 
                   avg_reports[label]['f1-score']])


    print(x)
    print('Accuracy: ', avg_reports['accuracy'])
def base_level_eval(users, predictions):
    """Uses the predctions to return the average of the ndcg impact at base level.
    Args:
        users: list of users ids
        predictions:predictions for users. PREDS HAVE TO be the same index ahas the users list
    Returns:
        average of ndcg
    """
    print('starting base_level_eval')
    results_algo = pd.read_csv(os.path.join(DATA_DIR, 'results_metadataset.csv'))
    base_impact = []
    base_impact_zeroes_most = []
    base_impact_zeroes_best = []
    count_users = 0
    count_users_less= 0
    count_users_same= 0
    for user_uid, pred in zip(users, predictions):


        val = results_algo.loc[ results_algo['original_id'] == user_uid, pred ]
        if pred == 'zeroes':
            val_zeroes = results_algo.loc[ results_algo['original_id'] == user_uid, 'most_popular_ndcg']
            best = results_algo.loc[ results_algo['original_id'] == user_uid]

            base_impact.append(val.values[0])
            base_impact_zeroes_most.append(val_zeroes.values[0])
            base_impact_zeroes_best.append(best.drop('original_id', 1).max(axis=1).values[0])
        else:
            base_impact.append(val.values[0])
            base_impact_zeroes_most.append(val.values[0])
            base_impact_zeroes_best.append(val.values[0])
    

        if len(val.values) > 1:
            raise Exception("More than one case")
        
        als_value = results_algo.loc[ results_algo['original_id'] == user_uid, 'als_ndcg' ]
        if val.values[0] > als_value.values[0]:
            if count_users == 0:
                print(val.values[0], als_value.values[0])
            count_users+=1
        elif val.values[0] == als_value.values[0]:
            if count_users_same < 5:
                print(val.values[0], als_value.values[0])
            count_users_same+=1
        else:
            if count_users_less == 0:
                print(val.values[0], als_value.values[0])
            count_users_less+=1
            
            
    print("%usesr that prediction ndcg is better than ALS ", count_users / len(users) )
    print("%usesr that prediction ndcg is same than ALS", count_users_same / len(users) )
    print("% users improved worse than", count_users_less / len(users) )

    return np.mean(base_impact), np.mean(base_impact_zeroes_most), np.mean(base_impact_zeroes_best)

# %% [markdown]
# #### Print

# %%
def print_report(avg_reports):
    from prettytable import PrettyTable
    x = PrettyTable()

    x.field_names = ["Algorithm", "Precision", "Recall", "F1"]

    for label in avg_reports.keys():
        if label in 'accuracy':
            x.add_row(['---','---','---','---'])
            continue
        x.add_row([label, 
                   avg_reports[label]['precision'], 
                   avg_reports[label]['recall'], 
                   avg_reports[label]['f1-score']])


    print(x)
    print('Accuracy: ', avg_reports['accuracy'])

# %%
def report_average(reports):
    mean_dict = dict()
    for label in reports[0].keys():
        dictionary = dict()

        if label in 'accuracy':
            mean_dict[label] = sum(d[label] for d in reports) / len(reports)
            continue

        for key in reports[0][label].keys():
            dictionary[key] = sum(d[label][key] for d in reports) / len(reports)
        mean_dict[label] = dictionary

    return mean_dict

# %% [markdown]
# ### Grid Search

# %%
param_grid = {
    'bootstrap': [True],
    'max_depth': [10 ,75, 150],
    'max_features': ['auto', 'sqrt', 'log2'],
    'n_estimators': [100, 250, 1000],
}

# %%
rf = RandomForestClassifier()
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, cv = 5, n_jobs = -1, verbose = 10)
grid_search.fit(inputs, target)

# %%
grid_search.best_params_
