# %%
import os
import shutil
import sys

import json

import numpy as np
from scipy import sparse
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sn
sn.set()

import pandas as pd
import implicit

from tqdm.notebook import tqdm

# %%
# Just choose the name of the dataset directory
dataset  = 'ml-20m'
DATA_DIR = '/Users/tomas/Documents/FEUP/Tese/data/' + dataset
PARSE_DATA_DIR = os.path.join(DATA_DIR, 'processed_70_15_15')

# %%
# K = 10
pre_meta_data_df = pd.read_csv(os.path.join(PARSE_DATA_DIR, 'total_results_k_10.csv'), header=0)

# %%
# K = 20
pre_meta_data_df = pd.read_csv(os.path.join(PARSE_DATA_DIR, 'total_results_k_20.csv'), header=0)

# %%
# K = 100
pre_meta_data_df = pd.read_csv(os.path.join(PARSE_DATA_DIR, 'total_results_k_100.csv'), header=0)

# %%
pre_meta_data_df = pre_meta_data_df.drop('uid', 1)

# %%
pre_meta_data_df = pre_meta_data_df.drop('knn_tfidf_ndcg', 1)
pre_meta_data_df = pre_meta_data_df.drop('knn_cos_ndcg', 1)
pre_meta_data_df = pre_meta_data_df.drop('knn_bm25_ndcg', 1)

# %%
pre_meta_data_df['zeroes'] = 0.000001

# %%
pre_meta_data_df.head()
# Out:
#    als_ndcg  bpr_ndcg  lmf_ndcg  most_popular_ndcg    zeroes
# 0  0.000000  0.227200  0.194959           0.000000  0.000001
# 1  0.351933  0.000000  0.270238           0.309358  0.000001
# 2  0.157293  0.226237  0.179672           0.000000  0.000001
# 3  0.183169  0.154812  0.356207           0.000000  0.000001
# 4  0.246336  0.224244  0.156438           0.397366  0.000001

# %%
pre_meta_data_dict = dict([(r[0], list(pre_meta_data_df.columns[np.argsort(list(r)[1::])])) \
    for r in list(pre_meta_data_df.to_records())])

# %%
pre_meta_data_dict
# Out:
# {0: ['als_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'lmf_ndcg'],
#  1: ['bpr_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'als_ndcg',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg'],
#  2: ['most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg'],
#  3: ['lmf_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg'],
#  4: ['bpr_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'lmf_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg'],
#  5: ['most_popular_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg'],
#  6: ['bpr_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg'],
#  7: ['zeroes',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  8: ['lmf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg',
#   'als_ndcg'],
#  9: ['als_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'most_popular_ndcg'],
#  10: ['zeroes',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'als_ndcg',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg'],
#  11: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg'],
#  12: ['knn_cos_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'als_ndcg'],
#  13: ['zeroes',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg'],
#  14: ['lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'bpr_ndcg'],
#  15: ['bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg'],
#  16: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg'],
#  17: ['als_ndcg',
#   'bpr_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'lmf_ndcg'],
#  18: ['most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg'],
#  19: ['lmf_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg'],
#  20: ['most_popular_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'lmf_ndcg'],
#  21: ['most_popular_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg'],
#  22: ['most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'als_ndcg'],
#  23: ['als_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg'],
#  24: ['knn_bm25_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'bpr_ndcg'],
#  25: ['zeroes',
#   'most_popular_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'lmf_ndcg'],
#  26: ['als_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'bpr_ndcg'],
#  27: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg'],
#  28: ['most_popular_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg'],
#  29: ['bpr_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg'],
#  30: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg'],
#  31: ['zeroes',
#   'bpr_ndcg',
#   'als_ndcg',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'lmf_ndcg'],
#  32: ['most_popular_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg'],
#  33: ['bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg'],
#  34: ['lmf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg',
#   'als_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  35: ['lmf_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg'],
#  36: ['bpr_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg'],
#  37: ['zeroes',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg'],
#  38: ['zeroes',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg'],
#  39: ['zeroes',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'lmf_ndcg'],
#  40: ['bpr_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg'],
#  41: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes'],
#  42: ['zeroes',
#   'als_ndcg',
#   'most_popular_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg'],
#  43: ['lmf_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'bpr_ndcg'],
#  44: ['most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'bpr_ndcg'],
#  45: ['lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg',
#   'bpr_ndcg',
#   'als_ndcg'],
#  46: ['knn_bm25_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'als_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg'],
#  47: ['bpr_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  48: ['zeroes',
#   'als_ndcg',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg'],
#  49: ['zeroes',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'als_ndcg'],
#  50: ['lmf_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'als_ndcg'],
#  51: ['lmf_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg'],
#  52: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes'],
#  53: ['zeroes',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg'],
#  54: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg'],
#  55: ['bpr_ndcg',
#   'lmf_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  56: ['most_popular_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'bpr_ndcg'],
#  57: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'most_popular_ndcg'],
#  58: ['most_popular_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg'],
#  59: ['zeroes',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg'],
#  60: ['bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg'],
#  61: ['lmf_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'als_ndcg'],
#  62: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  63: ['lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'bpr_ndcg'],
#  64: ['bpr_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'most_popular_ndcg'],
#  65: ['zeroes',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'bpr_ndcg'],
#  66: ['most_popular_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg'],
#  67: ['lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg'],
#  68: ['zeroes',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg'],
#  69: ['zeroes',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'bpr_ndcg'],
#  70: ['zeroes',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'als_ndcg'],
#  71: ['most_popular_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg'],
#  72: ['bpr_ndcg',
#   'lmf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  73: ['zeroes',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'lmf_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg'],
#  74: ['most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'als_ndcg',
#   'lmf_ndcg'],
#  75: ['bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg'],
#  76: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg'],
#  77: ['zeroes',
#   'bpr_ndcg',
#   'most_popular_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'lmf_ndcg'],
#  78: ['als_ndcg',
#   'lmf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg'],
#  79: ['most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg'],
#  80: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg'],
#  81: ['lmf_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'als_ndcg'],
#  82: ['lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'als_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  83: ['als_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'bpr_ndcg'],
#  84: ['most_popular_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'als_ndcg'],
#  85: ['most_popular_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg'],
#  86: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg'],
#  87: ['als_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'knn_bm25_ndcg'],
#  88: ['zeroes',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg'],
#  89: ['bpr_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'lmf_ndcg',
#   'als_ndcg'],
#  90: ['zeroes',
#   'most_popular_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  91: ['zeroes',
#   'most_popular_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg'],
#  92: ['lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg',
#   'als_ndcg',
#   'most_popular_ndcg'],
#  93: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes'],
#  94: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes'],
#  95: ['bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'als_ndcg'],
#  96: ['bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg'],
#  97: ['most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'als_ndcg',
#   'bpr_ndcg'],
#  98: ['most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  99: ['als_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'most_popular_ndcg',
#   'lmf_ndcg'],
#  100: ['als_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg'],
#  101: ['lmf_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg'],
#  102: ['zeroes',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg'],
#  103: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg'],
#  104: ['lmf_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg'],
#  105: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes'],
#  106: ['most_popular_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'lmf_ndcg'],
#  107: ['knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  108: ['als_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'bpr_ndcg'],
#  109: ['lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'most_popular_ndcg'],
#  110: ['zeroes',
#   'most_popular_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  111: ['most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg'],
#  112: ['als_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'bpr_ndcg'],
#  113: ['lmf_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg'],
#  114: ['most_popular_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg'],
#  115: ['lmf_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg'],
#  116: ['bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'als_ndcg'],
#  117: ['most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'als_ndcg'],
#  118: ['knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'als_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg'],
#  119: ['als_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg'],
#  120: ['most_popular_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'bpr_ndcg'],
#  121: ['zeroes',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg'],
#  122: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg'],
#  123: ['zeroes',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  124: ['zeroes',
#   'most_popular_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg'],
#  125: ['zeroes',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg'],
#  126: ['bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  127: ['zeroes',
#   'most_popular_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  128: ['als_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg'],
#  129: ['zeroes',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg'],
#  130: ['als_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'bpr_ndcg'],
#  131: ['knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'als_ndcg'],
#  132: ['lmf_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg'],
#  133: ['zeroes',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg'],
#  134: ['zeroes',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  135: ['most_popular_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg'],
#  136: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes'],
#  137: ['most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  138: ['most_popular_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg'],
#  139: ['lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'als_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  140: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes'],
#  141: ['lmf_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg'],
#  142: ['knn_bm25_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'als_ndcg'],
#  143: ['zeroes',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg'],
#  144: ['zeroes',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg'],
#  145: ['bpr_ndcg',
#   'lmf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  146: ['zeroes',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg'],
#  147: ['zeroes',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg'],
#  148: ['zeroes',
#   'most_popular_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg'],
#  149: ['bpr_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  150: ['most_popular_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg'],
#  151: ['bpr_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg',
#   'als_ndcg'],
#  152: ['zeroes',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg'],
#  153: ['most_popular_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'als_ndcg'],
#  154: ['als_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'bpr_ndcg'],
#  155: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg'],
#  156: ['zeroes',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg'],
#  157: ['zeroes',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg'],
#  158: ['als_ndcg',
#   'bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'lmf_ndcg'],
#  159: ['knn_bm25_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'als_ndcg',
#   'lmf_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg'],
#  160: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes'],
#  161: ['lmf_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg'],
#  162: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes'],
#  163: ['zeroes',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg'],
#  164: ['lmf_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg'],
#  165: ['bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg'],
#  166: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg'],
#  167: ['bpr_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  168: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  169: ['bpr_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'lmf_ndcg'],
#  170: ['lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg'],
#  171: ['als_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'bpr_ndcg'],
#  172: ['als_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  173: ['als_ndcg',
#   'bpr_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg'],
#  174: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg'],
#  175: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg'],
#  176: ['zeroes',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg'],
#  177: ['bpr_ndcg',
#   'lmf_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg'],
#  178: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  179: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg'],
#  180: ['zeroes',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg',
#   'als_ndcg'],
#  181: ['bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg'],
#  182: ['most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg'],
#  183: ['bpr_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  184: ['als_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  185: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes'],
#  186: ['als_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg'],
#  187: ['knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg',
#   'als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg'],
#  188: ['lmf_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  189: ['als_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg'],
#  190: ['knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg',
#   'lmf_ndcg'],
#  191: ['zeroes',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg',
#   'bpr_ndcg',
#   'als_ndcg',
#   'lmf_ndcg'],
#  192: ['bpr_ndcg',
#   'lmf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg'],
#  193: ['als_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'bpr_ndcg'],
#  194: ['zeroes',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'lmf_ndcg',
#   'als_ndcg'],
#  195: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg'],
#  196: ['bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'als_ndcg'],
#  197: ['zeroes',
#   'knn_cos_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg'],
#  198: ['bpr_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg'],
#  199: ['most_popular_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg'],
#  200: ['zeroes',
#   'most_popular_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg'],
#  201: ['bpr_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg'],
#  202: ['zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg'],
#  203: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes'],
#  204: ['lmf_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  205: ['most_popular_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  206: ['lmf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg',
#   'als_ndcg',
#   'bpr_ndcg'],
#  207: ['knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'lmf_ndcg'],
#  208: ['als_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'bpr_ndcg'],
#  209: ['most_popular_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'als_ndcg'],
#  210: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes'],
#  211: ['lmf_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'als_ndcg'],
#  212: ['bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg'],
#  213: ['most_popular_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg'],
#  214: ['bpr_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  215: ['most_popular_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg'],
#  216: ['als_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg'],
#  217: ['knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg',
#   'als_ndcg',
#   'most_popular_ndcg'],
#  218: ['bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg'],
#  219: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes'],
#  220: ['als_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'bpr_ndcg'],
#  221: ['als_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg'],
#  222: ['bpr_ndcg',
#   'lmf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg'],
#  223: ['zeroes',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  224: ['most_popular_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  225: ['bpr_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'als_ndcg',
#   'lmf_ndcg'],
#  226: ['most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg'],
#  227: ['knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg',
#   'als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg'],
#  228: ['lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  229: ['als_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'bpr_ndcg'],
#  230: ['zeroes',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  231: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes'],
#  232: ['bpr_ndcg',
#   'lmf_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg'],
#  233: ['bpr_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  234: ['zeroes',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg'],
#  235: ['zeroes',
#   'bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg'],
#  236: ['most_popular_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'bpr_ndcg'],
#  237: ['knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg'],
#  238: ['lmf_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg'],
#  239: ['lmf_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg'],
#  240: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg'],
#  241: ['most_popular_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  242: ['lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'bpr_ndcg',
#   'most_popular_ndcg'],
#  243: ['als_ndcg',
#   'lmf_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg'],
#  244: ['most_popular_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'bpr_ndcg'],
#  245: ['als_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'bpr_ndcg'],
#  246: ['bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  247: ['most_popular_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg'],
#  248: ['zeroes',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg'],
#  249: ['als_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'bpr_ndcg'],
#  250: ['als_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg'],
#  251: ['most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg'],
#  252: ['bpr_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg'],
#  253: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg'],
#  254: ['most_popular_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'als_ndcg'],
#  255: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg'],
#  256: ['knn_bm25_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'als_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg'],
#  257: ['most_popular_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg'],
#  258: ['lmf_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'als_ndcg'],
#  259: ['zeroes',
#   'als_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg'],
#  260: ['bpr_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg'],
#  261: ['bpr_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg'],
#  262: ['bpr_ndcg',
#   'lmf_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg'],
#  263: ['lmf_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg'],
#  264: ['zeroes',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg'],
#  265: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes'],
#  266: ['bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  267: ['lmf_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg'],
#  268: ['zeroes',
#   'most_popular_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'als_ndcg'],
#  269: ['lmf_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg'],
#  270: ['lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg'],
#  271: ['lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'als_ndcg'],
#  272: ['bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg'],
#  273: ['most_popular_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  274: ['bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg'],
#  275: ['knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'als_ndcg'],
#  276: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes'],
#  277: ['zeroes',
#   'most_popular_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg'],
#  278: ['lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'bpr_ndcg',
#   'most_popular_ndcg'],
#  279: ['lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg'],
#  280: ['bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg'],
#  281: ['bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  282: ['lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  283: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg'],
#  284: ['zeroes',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'bpr_ndcg'],
#  285: ['als_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'lmf_ndcg'],
#  286: ['lmf_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg'],
#  287: ['most_popular_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg'],
#  288: ['most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg'],
#  289: ['bpr_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg'],
#  290: ['most_popular_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'lmf_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg'],
#  291: ['zeroes',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'als_ndcg'],
#  292: ['zeroes',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg',
#   'als_ndcg'],
#  293: ['most_popular_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg'],
#  294: ['most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'als_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg'],
#  295: ['bpr_ndcg',
#   'lmf_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  296: ['als_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'bpr_ndcg'],
#  297: ['zeroes',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg'],
#  298: ['zeroes',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg',
#   'lmf_ndcg'],
#  299: ['zeroes',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg'],
#  300: ['als_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'lmf_ndcg'],
#  301: ['bpr_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'lmf_ndcg'],
#  302: ['most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg'],
#  303: ['als_ndcg',
#   'bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'lmf_ndcg'],
#  304: ['knn_bm25_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'als_ndcg',
#   'most_popular_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg'],
#  305: ['zeroes',
#   'als_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg'],
#  306: ['most_popular_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  307: ['zeroes',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'lmf_ndcg'],
#  308: ['zeroes',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg'],
#  309: ['lmf_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  310: ['bpr_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg'],
#  311: ['knn_bm25_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg'],
#  312: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes'],
#  313: ['most_popular_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg'],
#  314: ['lmf_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg'],
#  315: ['zeroes',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg'],
#  316: ['lmf_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  317: ['lmf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg',
#   'als_ndcg'],
#  318: ['als_ndcg',
#   'bpr_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg'],
#  319: ['bpr_ndcg',
#   'lmf_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  320: ['knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'bpr_ndcg'],
#  321: ['zeroes',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  322: ['most_popular_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'lmf_ndcg'],
#  323: ['lmf_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg'],
#  324: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg'],
#  325: ['als_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'bpr_ndcg'],
#  326: ['most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'lmf_ndcg'],
#  327: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg'],
#  328: ['lmf_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg'],
#  329: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  330: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg'],
#  331: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg'],
#  332: ['bpr_ndcg',
#   'lmf_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg'],
#  333: ['als_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'most_popular_ndcg'],
#  334: ['zeroes',
#   'most_popular_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'lmf_ndcg'],
#  335: ['zeroes',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'most_popular_ndcg',
#   'lmf_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg'],
#  336: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg'],
#  337: ['zeroes',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg'],
#  338: ['bpr_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg'],
#  339: ['zeroes',
#   'lmf_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg'],
#  340: ['als_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'bpr_ndcg'],
#  341: ['most_popular_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg'],
#  342: ['most_popular_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'als_ndcg'],
#  343: ['most_popular_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
# ...
#   'knn_cos_ndcg'],
#  886: ['bpr_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg'],
#  887: ['zeroes',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg'],
#  888: ['most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg'],
#  889: ['bpr_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg'],
#  890: ['bpr_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg'],
#  891: ['bpr_ndcg',
#   'lmf_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg'],
#  892: ['zeroes',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'lmf_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg'],
#  893: ['zeroes',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  894: ['als_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg'],
#  895: ['zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg'],
#  896: ['knn_tfidf_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg'],
#  897: ['zeroes',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  898: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes'],
#  899: ['zeroes',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'lmf_ndcg',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg',
#   'als_ndcg'],
#  900: ['zeroes',
#   'bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg'],
#  901: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'most_popular_ndcg'],
#  902: ['bpr_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg',
#   'lmf_ndcg'],
#  903: ['lmf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg'],
#  904: ['knn_bm25_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  905: ['zeroes',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'als_ndcg'],
#  906: ['zeroes',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  907: ['most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg'],
#  908: ['bpr_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg'],
#  909: ['als_ndcg',
#   'lmf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg'],
#  910: ['bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg'],
#  911: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg'],
#  912: ['lmf_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg'],
#  913: ['most_popular_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg'],
#  914: ['bpr_ndcg',
#   'lmf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'most_popular_ndcg'],
#  915: ['lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'bpr_ndcg'],
#  916: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg'],
#  917: ['lmf_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg'],
#  918: ['bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  919: ['zeroes',
#   'lmf_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg'],
#  920: ['bpr_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg'],
#  921: ['zeroes',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg'],
#  922: ['zeroes',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  923: ['lmf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg',
#   'bpr_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  924: ['als_ndcg',
#   'bpr_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg'],
#  925: ['zeroes',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'lmf_ndcg'],
#  926: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes'],
#  927: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg'],
#  928: ['zeroes',
#   'als_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg'],
#  929: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes'],
#  930: ['bpr_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'als_ndcg'],
#  931: ['zeroes',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg'],
#  932: ['bpr_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg'],
#  933: ['als_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg'],
#  934: ['bpr_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  935: ['most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg'],
#  936: ['zeroes',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg'],
#  937: ['zeroes',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg'],
#  938: ['als_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg'],
#  939: ['most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'als_ndcg'],
#  940: ['knn_bm25_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'als_ndcg',
#   'bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  941: ['zeroes',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg'],
#  942: ['most_popular_ndcg',
#   'knn_cos_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg'],
#  943: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes'],
#  944: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg'],
#  945: ['bpr_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  946: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes'],
#  947: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg'],
#  948: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg'],
#  949: ['zeroes',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'bpr_ndcg'],
#  950: ['zeroes',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'lmf_ndcg'],
#  951: ['als_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'bpr_ndcg'],
#  952: ['lmf_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'als_ndcg'],
#  953: ['zeroes',
#   'most_popular_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  954: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg'],
#  955: ['als_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg'],
#  956: ['most_popular_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg'],
#  957: ['bpr_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'most_popular_ndcg'],
#  958: ['zeroes',
#   'most_popular_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg'],
#  959: ['lmf_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  960: ['als_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'bpr_ndcg'],
#  961: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg'],
#  962: ['zeroes',
#   'most_popular_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg'],
#  963: ['most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg'],
#  964: ['zeroes',
#   'lmf_ndcg',
#   'als_ndcg',
#   'most_popular_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg'],
#  965: ['zeroes',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'als_ndcg'],
#  966: ['lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'bpr_ndcg'],
#  967: ['most_popular_ndcg',
#   'zeroes',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'als_ndcg'],
#  968: ['bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg'],
#  969: ['lmf_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'als_ndcg',
#   'bpr_ndcg'],
#  970: ['most_popular_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  971: ['zeroes',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg'],
#  972: ['lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg'],
#  973: ['als_ndcg',
#   'most_popular_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg'],
#  974: ['most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'als_ndcg'],
#  975: ['zeroes',
#   'most_popular_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'lmf_ndcg'],
#  976: ['zeroes',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'bpr_ndcg'],
#  977: ['als_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg'],
#  978: ['zeroes',
#   'knn_cos_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg',
#   'bpr_ndcg',
#   'als_ndcg'],
#  979: ['bpr_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg'],
#  980: ['zeroes',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'als_ndcg',
#   'bpr_ndcg'],
#  981: ['zeroes',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'lmf_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'most_popular_ndcg'],
#  982: ['zeroes',
#   'bpr_ndcg',
#   'most_popular_ndcg',
#   'lmf_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'knn_bm25_ndcg'],
#  983: ['als_ndcg',
#   'lmf_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg'],
#  984: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg'],
#  985: ['lmf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg',
#   'most_popular_ndcg'],
#  986: ['most_popular_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  987: ['bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'lmf_ndcg'],
#  988: ['zeroes',
#   'most_popular_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'als_ndcg',
#   'knn_tfidf_ndcg'],
#  989: ['lmf_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg'],
#  990: ['lmf_ndcg',
#   'zeroes',
#   'most_popular_ndcg',
#   'bpr_ndcg',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'knn_cos_ndcg'],
#  991: ['bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'knn_bm25_ndcg',
#   'knn_tfidf_ndcg',
#   'lmf_ndcg'],
#  992: ['als_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg'],
#  993: ['als_ndcg',
#   'lmf_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'bpr_ndcg',
#   'knn_cos_ndcg',
#   'most_popular_ndcg'],
#  994: ['lmf_ndcg',
#   'zeroes',
#   'als_ndcg',
#   'most_popular_ndcg',
#   'knn_bm25_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg'],
#  995: ['als_ndcg',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes'],
#  996: ['most_popular_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'knn_cos_ndcg',
#   'bpr_ndcg',
#   'knn_tfidf_ndcg',
#   'als_ndcg',
#   'knn_bm25_ndcg'],
#  997: ['als_ndcg',
#   'lmf_ndcg',
#   'most_popular_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_bm25_ndcg',
#   'zeroes',
#   'bpr_ndcg'],
#  998: ['zeroes',
#   'bpr_ndcg',
#   'lmf_ndcg',
#   'knn_bm25_ndcg',
#   'knn_cos_ndcg',
#   'knn_tfidf_ndcg',
#   'most_popular_ndcg',
#   'als_ndcg'],
#  999: ['knn_bm25_ndcg',
#   'zeroes',
#   'lmf_ndcg',
#   'als_ndcg',
#   'bpr_ndcg',
#   'most_popular_ndcg',
#   'knn_tfidf_ndcg',
#   'knn_cos_ndcg'],
#  ...}

# %%
pre_meta_data = pd.DataFrame.from_dict(pre_meta_data_dict,orient = 'index',columns=['fifth_place', 'fourth_place', 'third_place','second_place','first_place'])
#pre_meta_data = pd.DataFrame.from_dict(pre_meta_data_dict,orient = 'index',columns=['eight_place', 'seventh_place', 'sixth_place', 'fifth_place', 'fourth_place', 'third_place','second_place','first_place'])
#pre_meta_data = pd.DataFrame.from_dict(pre_meta_data_dict,orient = 'index',columns=['seventh_place', 'sixth_place', 'fifth_place', 'fourth_place', 'third_place','second_place','first_place'])

# %%
pre_meta_data.head(10)
# Out:
#          fifth_place       fourth_place        third_place       second_place  \
# 0           als_ndcg  most_popular_ndcg             zeroes           lmf_ndcg
# 1           bpr_ndcg             zeroes           lmf_ndcg  most_popular_ndcg
# 2  most_popular_ndcg             zeroes           als_ndcg           lmf_ndcg
# 3  most_popular_ndcg             zeroes           bpr_ndcg           als_ndcg
# 4             zeroes           lmf_ndcg           bpr_ndcg           als_ndcg
# 5  most_popular_ndcg             zeroes           als_ndcg           bpr_ndcg
# 6           bpr_ndcg           lmf_ndcg             zeroes  most_popular_ndcg
# 7             zeroes  most_popular_ndcg           bpr_ndcg           lmf_ndcg
# 8           lmf_ndcg             zeroes  most_popular_ndcg           als_ndcg
# 9           lmf_ndcg             zeroes           bpr_ndcg           als_ndcg
#
#          first_place
# 0           bpr_ndcg
# 1           als_ndcg
# 2           bpr_ndcg
# 3           lmf_ndcg
# 4  most_popular_ndcg
# 5           lmf_ndcg
# 6           als_ndcg
# 7           als_ndcg
# 8           bpr_ndcg
# 9  most_popular_ndcg

# %% [markdown]
# ### Helper

# %%
def plot_stats(labels, values, title):
    """Plot histogram and pie chart  
        Args:
            labels: labels to be used in the plots 
            values: values to be ploted
            title: title of the plots

        Returns:
        two plots
    """
    # Create arrays for the plot
    x_pos = np.arange(len(labels))
    
    # Build the plot
    fig, ax = plt.subplots()
    ax.bar(x_pos, values, align='center', alpha=0.8)
    ax.set_ylabel('count')
    ax.set_xticks(x_pos)
    ax.set_xticklabels(labels, rotation=90)
    ax.set_title(title)
    ax.yaxis.grid(True)

    # Save the figure and show
    plt.tight_layout()
    plt.show()
    
    fig_pie, ax_pie = plt.subplots()
    ax_pie.pie(values, labels=labels, colors= ['#eeefff','#FFFF33','#CCFF00','#eeefff','#eeefff','#eeefff','#eeefff','#eeefff'], autopct='%1.1f%%')
    ax_pie.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
    ax_pie.set_title(title)


    plt.show()
    
    
    
    return

# %% [markdown]
# ## Plots

# %% [markdown]
# #### Top Each place

# %%
for col in pre_meta_data.columns:
    print('--- plots of', col , ' ---')
    x_place = pre_meta_data[col].value_counts().to_dict()
    plot_stats(x_place.keys(), x_place.values(), 'plots of '+ col)
# Out:
# --- plots of fifth_place  ---
# --- plots of fourth_place  ---
# --- plots of third_place  ---
# --- plots of second_place  ---
# --- plots of first_place  ---

# %% [markdown]
# ### Top 2

# %%
duplas = pre_meta_data.groupby(["first_place", "second_place"]).size().sort_values(ascending=False).reset_index(name='count').head(10)

# %%
duplas_dict = dict( ("(1:" + duplas.loc[i, "first_place"] + ",2:" + duplas.loc[i,"second_place"] + ")", duplas.loc[i, "count"]) for i in range(len(duplas)))

# %%
plot_stats(duplas_dict.keys(), duplas_dict.values(), "top pairs")

# %% [markdown]
# ### Top 3

# %%
triplos = pre_meta_data.groupby(["first_place", "second_place", "third_place"]).size().sort_values(ascending=False).reset_index(name='count').head(10)

# %%
triplets_dict = dict( ("(1:" + triplos.loc[i, "first_place"] + ",2:" + triplos.loc[i,"second_place"] + ",3:" + triplos.loc[i,"third_place"] + ")", triplos.loc[i, "count"]) for i in range(len(duplas)))

# %%
plot_stats(triplets_dict.keys(), triplets_dict.values(), "top triplets")
