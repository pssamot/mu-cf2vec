# %%
import os
import shutil
import sys

import numpy as np
import pandas as pd

# %%
# Just choose the name of the dataset directory
dataset  = 'ml-20m'
DATA_DIR = '/Users/tomas/Documents/FEUP/Tese/data/ml-20m' + dataset
PARSE_DATA_DIR = os.path.join(DATA_DIR, 'processed_70_10_20/embeddings/vae')

# %%
embeddings = pd.read_csv(os.path.join(PARSE_DATA_DIR, 'embeddings.csv'),header=None)

# %%
embeddings.tail(100)
# Out:
#          0         1         2         3         4         5         6    \
# 286191  6191 -0.874143  0.285360 -0.008413 -0.001133  0.034814 -0.719977
# 286192  6192 -0.917600 -0.689493 -0.004023 -0.103825  0.055322  0.760492
# 286193  6193  0.002597 -0.045633  0.036157 -0.046635  0.092157  0.771723
# 286194  6194  0.239383 -0.445841 -0.032858 -0.063725 -0.041938 -0.114386
# 286195  6195 -0.283322 -0.133097  0.060083 -0.054447  0.041375 -0.087164
# 286196  6196 -0.154660  0.307333 -0.010278 -0.093571  0.052179 -0.208014
# 286197  6197 -0.011350  0.430136  0.023645 -0.102238  0.067407  0.187494
# 286198  6198  0.281009  0.372518  0.026300 -0.061100  0.112298 -0.201788
# 286199  6199 -0.537717 -0.000895  0.012567 -0.071842  0.053735 -0.137701
# 286200  6200  0.563845  0.893515  0.088098  0.011959  0.078210  0.131342
# 286201  6201 -0.070676 -0.194864 -0.025030 -0.031864  0.061700  0.147455
# 286202  6202  0.007937 -0.879923 -0.042151  0.038540  0.000314 -0.372076
# ...

# %%
embeddings = pd.read_csv(os.path.join(PARSE_DATA_DIR, 'embeddings.csv'),header=None)

# %%
embeddings.shape
# Out:
# (286291, 201)

# %%
embeddings_old = pd.read_csv(os.path.join(PARSE_DATA_DIR, 'embeddings_old.csv'),header=None)

# %%
embeddings_old.shape
# Out:
# (120000, 201)

# %% [markdown]
# ## OLD

# %%
raw_data = pd.read_csv(os.path.join(DATA_DIR, 'ratings.csv'), header=0)
raw_data = raw_data.sort_values(["userId", "movieId"], ascending = (True, True))

# %%
# binarize the data (only keep ratings >= 4)
clean_data = raw_data[raw_data['rating'] > 3.5]

# %%
clean_data.head(25)
# Out:
#     userId  movieId  rating   timestamp
# 6        1      151     4.0  1094785734
# 7        1      223     4.0  1112485573
# 8        1      253     4.0  1112484940
# 9        1      260     4.0  1112484826
# 10       1      293     4.0  1112484703
# 11       1      296     4.0  1112484767
# 12       1      318     4.0  1112484798
# 15       1      541     4.0  1112484603
# 22       1     1036     4.0  1112485480
# 23       1     1079     4.0  1094785665
# 26       1     1090     4.0  1112485453
# 27       1     1097     4.0  1112485701
# 30       1     1196     4.5  1112484742
# 31       1     1198     4.5  1112484624
# 32       1     1200     4.0  1112484560
# 35       1     1214     4.0  1094785977
# 36       1     1215     4.0  1094786082
# 38       1     1219     4.0  1094785994
# 40       1     1240     4.0  1112485401
# 43       1     1249     4.0  1112485382
# 44       1     1258     4.0  1094785994
# 45       1     1259     4.0  1112485440
# ...

# %%
raw_data.head(25)
# Out:
#     userId  movieId  rating   timestamp
# 0        1        2     3.5  1112486027
# 1        1       29     3.5  1112484676
# 2        1       32     3.5  1112484819
# 3        1       47     3.5  1112484727
# 4        1       50     3.5  1112484580
# 5        1      112     3.5  1094785740
# 6        1      151     4.0  1094785734
# 7        1      223     4.0  1112485573
# 8        1      253     4.0  1112484940
# 9        1      260     4.0  1112484826
# 10       1      293     4.0  1112484703
# 11       1      296     4.0  1112484767
# 12       1      318     4.0  1112484798
# 13       1      337     3.5  1094785709
# 14       1      367     3.5  1112485980
# 15       1      541     4.0  1112484603
# 16       1      589     3.5  1112485557
# 17       1      593     3.5  1112484661
# 18       1      653     3.0  1094785691
# 19       1      919     3.5  1094785621
# 20       1      924     3.5  1094785598
# 21       1     1009     3.5  1112486013
# ...

# %%
 train = pd.read_csv(os.path.join(PARSE_DATA_DIR, 'train.csv'))

# %%
train = train.sort_values(["uid", "sid"], ascending = (True, True))

# %%
train.head(320)
# Out:
#      uid   sid
# 63     0    28
# 79     0    31
# 68     0    46
# 53     0    49
# 11     0   110
# 10     0   149
# 111    0   220
# 84     0   250
# 80     0   257
# 67     0   290
# 73     0   293
# 76     0   315
# 7      0   333
# 54     0   537
# 108    0   583
# 61     0   587
# 5      0   644
# 1      0   901
# 0      0   906
# 102    0  1016
# 4      0  1056
# 90     0  1057
# 62     0  1066
# 99     0  1067
# 116    0  1074
# 55     0  1112
# 66     0  1167
# 70     0  1169
# 57     0  1171
# 50     0  1173
# ..   ...   ...
# 240    2  2974
# 236    2  2999
# 183    2  3043
# 189    2  4911
# 311    3     5
# 297    3     9
# 302    3    18
# 307    3    31
# 295    3   163
# 296    3   325
# 308    3   346
# 298    3   352
# 303    3   363
# 310    3   364
# 312    3   366
# 304    3   373
# 294    3   376
# 305    3   416
# 309    3   436
# 299    3   450
# 300    3   476
# 306    3   580
# 301    3   583
# 337    4     1
# 313    4    16
# 314    4    61
# ...

# %%
val = pd.read_csv(os.path.join(PARSE_DATA_DIR, 'validation.csv'))
val = val.sort_values(["uid", "sid"], ascending = (True, True))

# %%
val.head()
# Out:
#     uid   sid
# 0     0  1877
# 5     0  2048
# 15    0  2083
# 11    0  2084
# 2     0  2103

# %%
test = pd.read_csv(os.path.join(PARSE_DATA_DIR, 'test.csv'))
test = test.sort_values(["uid", "sid"], ascending = (True, True))

# %%
test.head()
# Out:
#     uid   sid
# 16    0     1
# 9     0   363
# 14    0   989
# 30    0  1476
# 35    0  1682
